# %% [markdown]
# # Аналитика рынка вакансий Москвы (название временное)

# %% [markdown]
# ### Импорт модулей

# %%
import requests
import pandas as pd
import time
import json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Получения датафрейма с помощью hh.ru.api

# %%
# Параметры запроса
keywords = ['sql', 'python', 'javascript', 'c++', '.NET'] #ключевые слова в вакансиях
hh_area = 1  # Пример кода региона (например, 1 - Москва)

# URL для запроса вакансий
url = 'https://api.hh.ru/vacancies'


# Функция для получения данных о метро
def get_metro_data(query, area):
    params = {
        'text': query,
        'area': area,
        'clusters': 'true',
        'per_page': 100,
        'page': 0
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        clusters = data.get('clusters', [])
        for cluster in clusters:
            if cluster['name'] == 'Метро':
                return cluster['items']
    return []

# Функция для получения вакансий по метро
def get_vacancies_by_metro(query, area, metro_id, page):
    params = {
        'text': query,
        'area': area,
        'metro': metro_id,
        'per_page': 100,
        'page': page
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('items', [])
    return []

# Список для хранения всех вакансий
all_vacancies = []

# Обработка каждого ключевого слова
for keyword in keywords:
    metro_data = get_metro_data(keyword, hh_area)

    # Обработка данных о метро
    for metro in metro_data:
        if 'metro_station' in metro:
            metro_id = metro['metro_station']['id']
            count = metro['count']
            pages = count // 100 + (count % 100 > 0)

            for page in range(pages):
                vacancies = get_vacancies_by_metro(keyword, hh_area, metro_id, page)
                all_vacancies.extend(vacancies)
                time.sleep(1.5)  # Пауза между запросами

# Создание DataFrame из полученных вакансий
df = pd.DataFrame(all_vacancies)

# Развертывание столбцов salary и snippet
df = pd.concat([df.drop(['salary', 'snippet'], axis=1),
                df['salary'].apply(pd.Series).add_prefix('salary.'),
                df['snippet'].apply(pd.Series)], axis=1)

# Преобразование столбцов с JSON-данными в строки
df['area'] = df['area'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['type'] = df['type'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['address'] = df['address'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['employer'] = df['employer'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['contacts'] = df['contacts'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['schedule'] = df['schedule'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['working_days'] = df['working_days'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['working_time_intervals'] = df['working_time_intervals'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['working_time_modes'] = df['working_time_modes'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['professional_roles'] = df['professional_roles'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['experience'] = df['experience'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df['employment'] = df['employment'].apply(lambda x: json.dumps(x, ensure_ascii=False))
df = df.loc[:, df.nunique() > 1]

# %% [markdown]
# ### Подготовка датафрейма

# %%
# Преобразование JSON-строк в словари
json_columns = ['area', 'type', 'address', 'employer', 'schedule', 'experience', 'employment']
for col in json_columns:
    df[col] = df[col].apply(lambda x: json.loads(x) if pd.notnull(x) and isinstance(x, str) and x.strip() else x)

# Обработка пропущенных значений
# Удаление строк с пропущенными значениями в критически важных полях
df.dropna(subset=['id', 'premium', 'name', 'department'], inplace=True)

# Заполнение пропущенных значений в менее важных полях
df['has_test'] = df['has_test'].fillna(False).infer_objects(copy=False)
df['response_letter_required'] = df['response_letter_required'].fillna(False).infer_objects(copy=False)
df['archived'] = df['archived'].fillna(False).infer_objects(copy=False)
df['show_logo_in_search'] = df['show_logo_in_search'].fillna(False).infer_objects(copy=False)
df['is_adv_vacancy'] = df['is_adv_vacancy'].fillna(False).infer_objects(copy=False)
df['salary.from'] = df['salary.from'].fillna(0).infer_objects(copy=False)
df['salary.to'] = df['salary.to'].fillna(0).infer_objects(copy=False)
df['salary.currency'] = df['salary.currency'].fillna('Unknown').infer_objects(copy=False)
df['salary.gross'] = df['salary.gross'].fillna(False).infer_objects(copy=False)

# Обработка аномальных значений
# Пример: удаление строк с отрицательными значениями в поле 'salary.from'
df = df[df['salary.from'] >= 0]

# Нормализация данных
df['name'] = df['name'].apply(lambda x: x.lower().strip() if isinstance(x, str) else x)
df['department'] = df['department'].apply(lambda x: x.lower().strip() if isinstance(x, str) else x)

# Удаление нерелевантных столбцов
df.drop(columns=['url', 'address', 'apply_alternate_url', 'alternate_url', 'requirement', 'responsibility',
                 'response_url', 'sort_point_distance', 'department', 'area', 'adv_response_url', 'adv_context'], inplace=True)

df['type'] = df['type'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
df['experience'] = df['experience'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
df['schedule'] = df['schedule'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
df['employment'] = df['employment'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
df['professional_roles'] = df['professional_roles'].apply(lambda x: x.get('name') if isinstance(x, dict) else x)
df['employer_id'] = df['employer'].apply(lambda x: x['id'])
df['employer_name'] = df['employer'].apply(lambda x: x['name'])
df['professional_roles'] = df['professional_roles'].apply(lambda x: x.get('name') if isinstance(x, dict) else x)

# Преобразование дат
df['published_at'] = pd.to_datetime(df['published_at'])
df['created_at'] = pd.to_datetime(df['created_at'])
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_25076\1193477093.py:14: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['show_logo_in_search'] = df['show_logo_in_search'].fillna(False).infer_objects(copy=False)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_25076\1193477093.py:19: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['salary.gross'] = df['salary.gross'].fillna(False).infer_objects(copy=False)

# %%
df.head()
# Out:
#            id  premium                                 name  has_test  \
# 14  108560191    False                  финансовый аналитик     False
# 18  108982321    False         младший продуктовый аналитик     False
# 19  108010328    False        руководитель группы поддержки     False
# 20  108912669    False  аналитик (коммерческое направление)     False
# 21  107660949    False               стажёр-аналитик данных      True
#
#     response_letter_required  type              published_at  \
# 14                     False  open 2024-10-13 15:41:40+03:00
# 18                     False  open 2024-10-21 15:55:23+03:00
# 19                     False  open 2024-10-01 16:45:02+03:00
# 20                     False  open 2024-10-20 20:21:43+03:00
# 21                     False  open 2024-10-23 17:57:07+03:00
#
#                   created_at  archived  show_logo_in_search  ...  \
# 14 2024-10-13 15:41:40+03:00     False                False  ...
# ...

# %%
df.to_csv('firstData.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('firstData.csv')
#
# NameError: name 'df' is not defined

# %%
# Преобразование категориальных признаков
df['premium'] = df['premium'].astype(int)
df['has_test'] = df['has_test'].astype(int)
df['response_letter_required'] = df['response_letter_required'].astype(int)
df['archived'] = df['archived'].astype(int)
df['show_logo_in_search'] = df['show_logo_in_search'].astype(int)
df['accept_temporary'] = df['accept_temporary'].astype(int)
df['accept_incomplete_resumes'] = df['accept_incomplete_resumes'].astype(int)
df['is_adv_vacancy'] = df['is_adv_vacancy'].astype(int)
df['salary.gross'] = df['salary.gross'].astype(int)

# Удаление ненужных столбцов
df.drop(columns=['employer', 'relations', 'working_days', 'working_time_intervals', 'working_time_modes', 'contacts', 'insider_interview', 'branding'], inplace=True)

# Кодирование категориальных признаков
label_encoder = LabelEncoder()
df['name'] = label_encoder.fit_transform(df['name'])
df['type'] = label_encoder.fit_transform(df['type'])
df['employer_name'] = label_encoder.fit_transform(df['employer_name'])
df['schedule'] = label_encoder.fit_transform(df['schedule'])
df['professional_roles'] = label_encoder.fit_transform(df['professional_roles'])
df['experience'] = label_encoder.fit_transform(df['experience'])
df['employment'] = label_encoder.fit_transform(df['employment'])
df['salary.currency'] = label_encoder.fit_transform(df['salary.currency'])

df = df.loc[:, df.nunique() > 1]

# %%
df.head()
# Out:
#            id  premium  name  has_test  response_letter_required  \
# 14  108560191        0   953         0                         0
# 18  108982321        0   599         0                         0
# 19  108010328        0   707         0                         0
# 20  108912669        0   290         0                         0
# 21  107660949        0   884         1                         0
#
#                 published_at                created_at  archived  \
# 14 2024-10-13 15:41:40+03:00 2024-10-13 15:41:40+03:00         0
# 18 2024-10-21 15:55:23+03:00 2024-10-21 15:55:23+03:00         0
# 19 2024-10-01 16:45:02+03:00 2024-10-01 16:45:02+03:00         0
# 20 2024-10-20 20:21:43+03:00 2024-10-20 20:21:43+03:00         0
# 21 2024-10-23 17:57:07+03:00 2024-10-23 17:57:07+03:00         0
#
#     show_logo_in_search  schedule  professional_roles  \
# 14                    0         1                  17
# 18                    1         1                  29
# ...

# %% [markdown]
# ### Визуализация данных

# %%
# Визуализация корреляции признаков
corr_matrix = df.corr

plt.figure(figsize = (20, 20))
sns.heatmap(corr_matrix, fmt=".1f", linewidth=.5, annot=True, annot_kws={"size": 13})
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
df.to_csv('data.csv')

# %% [markdown]
# - **premium**: Флаг, указывающий, является ли вакансия премиум (например, с дополнительными услугами или приоритетным размещением).
# - **name**: Название вакансии.
# - **has_test**: Флаг, указывающий, требуется ли прохождение теста для этой вакансии.
# - **response_letter_required**: Флаг, указывающий, требуется ли откликнувшемуся кандидату написать сопроводительное письмо.
# - **published_at**: Дата и время публикации вакансии.
# - **created_at**: Дата и время создания вакансии.
# - **archived**: Флаг, указывающий, архивирована ли вакансия.
# - **show_logo_in_search**: Флаг, указывающий, отображается ли логотип компании в результатах поиска.
# - **schedule**: График работы (например, полный рабочий день, частичная занятость и т.д.).
# - **professional_roles**: Профессиональные роли, которые подходят для этой вакансии.
# - **accept_incomplete_resumes**: Флаг, указывающий, принимаются ли неполные резюме.
# - **experience**: Требуемый опыт работы.
# - **employment**: Тип занятости (например, полная занятость, временная работа и т.д.).
# - **salary.from**: Нижняя граница зарплаты.
# - **salary.to**: Верхняя граница зарплаты.
# - **salary.currency**: Валюта зарплаты.
# - **salary.gross**: Флаг, указывающий, является ли зарплата брутто (до вычета налогов).
# - **employer_id**: Уникальный идентификатор работодателя.
# - **employer_name**: Название компании-работодателя.
